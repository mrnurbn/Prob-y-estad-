# %% [markdown]
# #LECTURA DE DATOS
# ## BASE DE DATOS ALMACENA, AGRUPA Y CODIFICA ESTRUCTURAS DE DATOS
#
# ### INFORMACIÓN:
# - NUMERICA
# - OBJETOS
# - ETIQUETAS
#
# ### BÚSQUEDA DE INFORMACIÓN (FUENTES):
# - WIKIPEDIA
# - KAGGLE
# - INEGI
#
# ###EXCEL(.xlxs, .CSV, .txt)
#
# BUSCAR BASE DE DATOS
# ¿POR QUÉ ES INTERESANTE PARA EL GRUPO?
# DETALLES DE LA BASE DE DATOS
# ESCRIBIR EN LA BASE DE DATOS

# %%
import pandas as pd

# %%
data = pd.read_csv('top50.csv', encoding='ISO-8859-1')
data
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %% [markdown]
# ## DETALLES DE LA BASE DE DATOS:
# - INCLUYE ATRIBUTOS POCO CONVENCIONALES DE LAS CANCIONES DEL TOP 50 DEL AÑO 2019 TALES COMO: DECIBELES, BEATS POR MINUTO , QUE TAN BAILABLE ES Y "SPEECHINESS"
# - LA COLUMNA DE DECIBELES ES LA ÚNICA QUE PRESENTA VALORES NEGATIVOS
# - EL ATRIBUTO POPULARITY MÁS ALTO NO ES EL MISMO DE LA CANCIÓN EN EL LUGAR NÚMERO 1
# - HAY REPETICIÓN DE ARTISTAS Y GÉNEROS
# - SE PODRÍA HACER UNA GRÁFICA DE CORRELACIÓN ENTRE TODAS LAS VARIABLES PARA OBSERVAR SI HAY ALGO QUE DETERMINE QUE ESTÉN EN EL TOP 50

# %% [markdown]
# ## ¿Por qué es interesante para el grupo?
#
# - Está base de dato es interesante para el grupo ya que todos escuchamos música y una de las plataformas más utilizada es Spotify.
# - Otra razón por la que es interesante se debe a que se despierta cierta curiosidad de saber cuales son las canciones favoritas y más escuchadas de la gente durante un año, tomando en cuenta todas las que salen en ese año
#
# Este tema es uno de los temas interesantes para el grupo ya que la mayoría de la sociedad escucha múscia de todo tipo. Esto ocasiona una cierta curiosidad de poder llegar a saber cuales son las canciones más escuchadas y favoritas de las personas de todas las que salieron durante cierto año. Asimismo, quieres saber cuál es el genero más escuhado dentro de la sociedad.
# Al tener este dato sobre el porque puede llegar a parecer interesante estos datos e información para el grupo podemos concluir que el conocer que datos se toman en cuenta para poder seleccionar los top 50 durante cierto año es interesante, así como también aprender a interpretar los datos de la manera correcta. En conclusión es un tema que despierta curiosidad e intriga.

# %% [markdown]
# ## MÉTODOS EN PANDAS

# %%
data.shape #cuantos renglones y cuantas columnas de la matriz. 1 x 1 es un vector
# Out:
# (50, 14)

# %%
data.ndim #dimension como objeto de pyhton, si es 1 es vector y si es 2 es matriz
# Out:
# 2

# %%
data.info() #resumen de la base de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
data.describe() #estadística descriptiva de la base de datos
# Out:
#        Unnamed: 0  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count    50.00000         50.000000  50.000000      50.00000       50.000000
# mean     25.50000        120.060000  64.060000      71.38000       -5.660000
# std      14.57738         30.898392  14.231913      11.92988        2.056448
# min       1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%      13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%      25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%      37.75000        137.500000  74.750000      79.75000       -4.000000
# max      50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# ...

# %% [markdown]
# ##SLICE: REBANAR A LA BASE DE DATOS

# %%
data['Track.Name'] #parte de la base de datos que tiene la columna nombre de canción
# Out:
# 0                                              Señorita
# 1                                                 China
# 2                         boyfriend (with Social House)
# 3                       Beautiful People (feat. Khalid)
# 4                           Goodbyes (Feat. Young Thug)
# 5                     I Don't Care (with Justin Bieber)
# 6                                                Ransom
# 7                                     How Do You Sleep?
# 8                                 Old Town Road - Remix
# 9                                               bad guy
# 10                                             Callaita
# 11                Loco Contigo (feat. J. Balvin & Tyga)
# 12                                    Someone You Loved
# 13                                   Otro Trago - Remix
# 14             Money In The Grave (Drake ft. Rick Ross)
# 15                            No Guidance (feat. Drake)
# 16                                           LA CANCIÓN
# ...

# %%
data[["Artist.Name", "Genre", "Beats.Per.Minute"]] #varias columnas
# Out:
#          Artist.Name             Genre  Beats.Per.Minute
# 0       Shawn Mendes      canadian pop               117
# 1           Anuel AA    reggaeton flow               105
# 2      Ariana Grande         dance pop               190
# 3         Ed Sheeran               pop                93
# 4        Post Malone           dfw rap               150
# 5         Ed Sheeran               pop               102
# 6          Lil Tecca        trap music               180
# 7          Sam Smith               pop               111
# 8          Lil Nas X       country rap               136
# 9      Billie Eilish        electropop               135
# 10         Bad Bunny         reggaeton               176
# 11          DJ Snake         dance pop                96
# 12     Lewis Capaldi               pop               110
# 13              Sech    panamanian pop               176
# 14             Drake  canadian hip hop               101
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0                         Track.Name    Artist.Name  \
# 0           1                           Señorita   Shawn Mendes
# 1           2                              China       Anuel AA
# 2           3      boyfriend (with Social House)  Ariana Grande
# 3           4    Beautiful People (feat. Khalid)     Ed Sheeran
# 4           5        Goodbyes (Feat. Young Thug)    Post Malone
# 5           6  I Don't Care (with Justin Bieber)     Ed Sheeran
# 6           7                             Ransom      Lil Tecca
# 7           8                  How Do You Sleep?      Sam Smith
# 8           9              Old Town Road - Remix      Lil Nas X
# 9          10                            bad guy  Billie Eilish
#
#             Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 0    canadian pop               117      55            76              -6
# 1  reggaeton flow               105      81            79              -4
# ...

# %%
data.tail()
# Out:
#     Unnamed: 0                                     Track.Name  \
# 45          46                                One Thing Right
# 46          47                                      Te Robaré
# 47          48                                        Happier
# 48          49                                  Call You Mine
# 49          50  Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name    Genre  Beats.Per.Minute  Energy  Danceability  \
# 45        Marshmello  brostep                88      62            66
# 46         Nicky Jam    latin               176      75            67
# 47        Marshmello  brostep               100      79            69
# 48  The Chainsmokers      edm               104      70            59
# 49        Ed Sheeran      pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 45              -2        58        44      182               7             5
# ...

# %% [markdown]
# ##Renglones no tiene una etiqueta como las columnas
# para acceder es: nombre_de_la_base_dedatos.iloc[índice]

# %%
data.iloc[0]
# Out:
# Unnamed: 0                     1
# Track.Name              Señorita
# Artist.Name         Shawn Mendes
# Genre               canadian pop
# Beats.Per.Minute             117
# Energy                        55
# Danceability                  76
# Loudness..dB..                -6
# Liveness                       8
# Valence.                      75
# Length.                      191
# Acousticness..                 4
# Speechiness.                   3
# Popularity                    79
# Name: 0, dtype: object

# %%
data.iloc[0:1]
# Out:
#    Unnamed: 0 Track.Name   Artist.Name         Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes  canadian pop               117
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
#
#    Acousticness..  Speechiness.  Popularity
# 0               4             3          79

# %%
data.iloc[0:5] ##mismo que head
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
import numpy as np
import pandas as pd

np.random.seed(1234)
df = pd.DataFrame(np.random.randn(10,4), columns = ["Col1", "Col2", "Col3", "Col4"])
boxplot = df.boxplot(column =["Col1", "Col2", "Col3"])

# %%
df["Col1"].describe()
# Out:
# count    10.000000
# mean      0.323001
# std       0.640899
# min      -0.720589
# 25%      -0.133407
# 50%       0.265083
# 75%       0.832852
# max       1.318152
# Name: Col1, dtype: float64

# %%
data.sort_values('Beats.Per.Minute', ascending=False).head(20)
# Out:
#     Unnamed: 0                      Track.Name     Artist.Name  \
# 2            3   boyfriend (with Social House)   Ariana Grande
# 6            7                          Ransom       Lil Tecca
# 10          11                        Callaita       Bad Bunny
# 36          37                      Otro Trago            Sech
# 46          47                       Te Robaré       Nicky Jam
# 16          17                      LA CANCIÓN        J Balvin
# 13          14              Otro Trago - Remix            Sech
# 19          20                     Truth Hurts           Lizzo
# 21          22                          Panini       Lil Nas X
# 37          38  Antisocial (with Travis Scott)      Ed Sheeran
# 4            5     Goodbyes (Feat. Young Thug)     Post Malone
# 31          32                         7 rings   Ariana Grande
# 38          39                          Sucker  Jonas Brothers
# 8            9           Old Town Road - Remix       Lil Nas X
# ...

# %%
#quitar columnas
data.drop(columns=['Danceability'])
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
df1=data[['Track.Name', 'Artist.Name']].head(20)
df1
# Out:
#                                        Track.Name    Artist.Name
# 0                                        Señorita   Shawn Mendes
# 1                                           China       Anuel AA
# 2                   boyfriend (with Social House)  Ariana Grande
# 3                 Beautiful People (feat. Khalid)     Ed Sheeran
# 4                     Goodbyes (Feat. Young Thug)    Post Malone
# 5               I Don't Care (with Justin Bieber)     Ed Sheeran
# 6                                          Ransom      Lil Tecca
# 7                               How Do You Sleep?      Sam Smith
# 8                           Old Town Road - Remix      Lil Nas X
# 9                                         bad guy  Billie Eilish
# 10                                       Callaita      Bad Bunny
# 11          Loco Contigo (feat. J. Balvin & Tyga)       DJ Snake
# 12                              Someone You Loved  Lewis Capaldi
# ...

# %%
df2= data[['Genre', 'Beats.Per.Minute']].head(20)
df2
# Out:
#                Genre  Beats.Per.Minute
# 0       canadian pop               117
# 1     reggaeton flow               105
# 2          dance pop               190
# 3                pop                93
# 4            dfw rap               150
# 5                pop               102
# 6         trap music               180
# 7                pop               111
# 8        country rap               136
# 9         electropop               135
# 10         reggaeton               176
# 11         dance pop                96
# 12               pop               110
# 13    panamanian pop               176
# 14  canadian hip hop               101
# 15         dance pop                93
# 16             latin               176
# 17           dfw rap                90
# 18  canadian hip hop               130
# 19       escape room               158

# %%
#para concatenar
df_concat = pd.concat((df1,df2), axis=1) #axis es que lo esta pegando por columnas 
df_concat
# Out:
#                                        Track.Name    Artist.Name  \
# 0                                        Señorita   Shawn Mendes
# 1                                           China       Anuel AA
# 2                   boyfriend (with Social House)  Ariana Grande
# 3                 Beautiful People (feat. Khalid)     Ed Sheeran
# 4                     Goodbyes (Feat. Young Thug)    Post Malone
# 5               I Don't Care (with Justin Bieber)     Ed Sheeran
# 6                                          Ransom      Lil Tecca
# 7                               How Do You Sleep?      Sam Smith
# 8                           Old Town Road - Remix      Lil Nas X
# 9                                         bad guy  Billie Eilish
# 10                                       Callaita      Bad Bunny
# 11          Loco Contigo (feat. J. Balvin & Tyga)       DJ Snake
# 12                              Someone You Loved  Lewis Capaldi
# ...

# %%
data['Popularity'] > 85
#solo me dice si las canciones estuvieron arriba de 85 de popularidad
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23     True
# 24     True
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30    False
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38    False
# 39    False
# 40     True
# 41     True
# 42     True
# 43    False
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49    False
# Name: Popularity, dtype: bool

# %%
df_concat[df_concat['Beats.Per.Minute'] > 160]
#aqui te pone la base de datos de la condicion
# Out:
#                        Track.Name    Artist.Name           Genre  \
# 2   boyfriend (with Social House)  Ariana Grande       dance pop
# 6                          Ransom      Lil Tecca      trap music
# 10                       Callaita      Bad Bunny       reggaeton
# 13             Otro Trago - Remix           Sech  panamanian pop
# 16                     LA CANCIÓN       J Balvin           latin
#
#     Beats.Per.Minute
# 2                190
# 6                180
# 10               176
# 13               176
# 16               176
